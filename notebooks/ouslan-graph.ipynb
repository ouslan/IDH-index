# %%
import pandas as pd
import plotext as plt
import numpy as np
from scipy.stats import gmean
import world_bank_data as wb
import os 
os.chdir('..')
import src.data.IDH

# %%
pct = (0.8404041762761011 - 0.8357769647277158)/ 0.8357769647277158 * 100
print(pct)
# Out:
# 0.5536419097040777

# %%
df = pd.read_csv('data/processed/idh_index.csv')

# %%
df["growth_health"] = df[]
# Out:
#    Year  health_index  health_index_ajusted  income_index  \
# 0  2012          0.90                  0.83          0.81
# 1  2013          0.90                  0.83          0.81
# 2  2014          0.91                  0.83          0.81
# 3  2015          0.92                  0.84          0.81
# 4  2016          0.93                  0.85          0.81
# 5  2017          0.91                  0.84          0.81
# 6  2018          0.92                  0.85          0.81
# 7  2019          0.91                  0.84          0.82
# 8  2020          0.89                  0.82          0.81
# 9  2021          0.93                  0.85          0.83
#
#    income_index_ajusted  edu_index  edu_index_ajusted  index  index_ajusted
# 0                  0.50       0.84               0.74   0.85           0.67
# 1                  0.50       0.84               0.75   0.85           0.68
# 2                  0.50       0.84               0.76   0.85           0.68
# 3                  0.50       0.85               0.76   0.86           0.68
# 4                  0.50       0.85               0.77   0.86           0.69
# 5                  0.50       0.86               0.77   0.86           0.69
# 6                  0.50       0.86               0.78   0.86           0.69
# 7                  0.50       0.87               0.79   0.87           0.69
# 8                  0.50       0.87               0.79   0.86           0.69
# 9                  0.51       0.87               0.80   0.88           0.70

# %%
plt.plot(df['Year'], df['index'])
plt.title('Idh Index')
plt.xlabel('Year')
plt.ylabel('Idh Index')
plt.show()
# Out:
#                                        Idh Index
#       ┌────────────────────────────────────────────────────────────────────────┐
# 0.8834┤                               ▄▚                                       │
#       │                             ▄▀  ▀▖                                     │
#       │                           ▄▀     ▝▚           ▗                       ▗│
# 0.8806┤                         ▄▀         ▀▖      ▗▄▀▘▀▀▚▄▄                 ▗▘│
#       │                       ▗▀            ▝▚  ▗▄▀▘        ▀▀▀▖            ▗▘ │
# 0.8778┤                      ▗▘               ▀▀▘              ▝▚          ▞▘  │
#       │                     ▄▘                                   ▀▄       ▞    │
#       │                    ▞                                       ▚▖   ▗▀     │
# 0.8750┤                  ▗▞                                         ▝▄ ▗▘      │
#       │                 ▗▘                                            ▀▘       │
#       │                ▄▘                                                      │
# 0.8722┤             ▄▞▀                                                        │
#       │          ▄▞▀                                                           │
# 0.8694┤       ▄▀▀                                                              │
#       │     ▄▀                                                                 │
#       │  ▗▞▀                                                                   │
# 0.8666┤▄▞▘                                                                     │
#       └┬─────────────────┬─────────────────┬────────────────┬─────────────────┬┘
#     2012.0            2014.2            2016.5           2018.8          2021.0
# Idh Index                                Year
