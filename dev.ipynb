# %%
import pandas as pd
import numpy as np
import world_bank_data as wb
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# GNI per capita, Atlas method (current US$)
df_gnp_current = pd.DataFrame(wb.get_series('NY.GNP.PCAP.CD', country='PR', simplify_index=True))
df_gnp_current.reset_index(inplace=True)
df_gnp_current.rename(columns={'NY.GNP.PCAP.CD': 'gnp_current'}, inplace=True)

df_gnp_2017 = pd.DataFrame(wb.get_series('NY.GNP.PCAP.PP.KD', country='PR', simplify_index=True))
df_gnp_2017.reset_index(inplace=True)
df_gnp_2017.rename(columns={'NY.GNP.PCAP.PP.KD': 'gnp_2017'}, inplace=True)

# Merge on year
df_gnp = pd.merge(df_gnp_current, df_gnp_2017, on='gnp_2017', how='left')

# Save to CSV
df_gnp.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 11
#       8 df_gnp_2017.rename(columns={'NY.GNP.PCAP.PP.KD': 'gnp_2017'}, inplace=True)
#      10 # Merge on year
# ---> 11 df_gnp = pd.merge(df_gnp_current, df_gnp_2017, on='gnp_2017', how='left')
#      13 # Save to CSV
#      14 df_gnp.head()
#
# File ~/anaconda3/envs/research/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
# ...

# %%
# plot the data 
plt = sns.scatterplot(x=df_gnp['Year'], y=df_gnp['gnp'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 # plot the data
#       2 plt = sns.scatterplot(x=df_gnp['Year'], y=df_gnp['gnp'])
# ----> 3 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'show'
